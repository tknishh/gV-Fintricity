# %%
import pandas as pd

# Load CSV file into DataFrame
df = pd.read_csv('./data/gri_ghg_protocol.csv')

# View the first 5 rows of the DataFrame
print(df.head)
# Out:
# <bound method NDFrame.head of                                        ID        TYPE  \
# 0    34cb5a35-0694-406d-990e-9eaa6b321880       Layer
# 1    8c040a69-2802-449e-b92c-8fcacb240517      Object
# 2    4c094eca-bc6d-43e7-947e-232982a1ac39   Attribute
# 3    99688868-3a0e-4a30-922d-3a834c97c26c  Transition
# 4    f753e076-f7ec-474e-a495-2593f2c1ea75      Object
# ..                                    ...         ...
# 97   20c1b341-b7d5-46e6-aaae-1f156e256428   Attribute
# 98   6f3d3bb2-dd1e-4432-bfbb-a927e09f1af2   Attribute
# 99   0c40a8d7-806f-4171-8e87-74bc1e3bf6d1   Attribute
# 100  a54a9920-1b83-4293-828e-4bf72af2ceec   Attribute
# 101  5954281b-63e9-487b-8cae-f7b87a28c35c   Attribute
#
#                                    PARENT                            NAME  \
# 0                                     NaN               GRI 305 Emissions
# 1    34cb5a35-0694-406d-990e-9eaa6b321880                Disclosure 305-1
# ...

# %%
df
# Out:
#                                        ID        TYPE  \
# 0    34cb5a35-0694-406d-990e-9eaa6b321880       Layer
# 1    8c040a69-2802-449e-b92c-8fcacb240517      Object
# 2    4c094eca-bc6d-43e7-947e-232982a1ac39   Attribute
# 3    99688868-3a0e-4a30-922d-3a834c97c26c  Transition
# 4    f753e076-f7ec-474e-a495-2593f2c1ea75      Object
# ..                                    ...         ...
# 97   20c1b341-b7d5-46e6-aaae-1f156e256428   Attribute
# 98   6f3d3bb2-dd1e-4432-bfbb-a927e09f1af2   Attribute
# 99   0c40a8d7-806f-4171-8e87-74bc1e3bf6d1   Attribute
# 100  a54a9920-1b83-4293-828e-4bf72af2ceec   Attribute
# 101  5954281b-63e9-487b-8cae-f7b87a28c35c   Attribute
#
#                                    PARENT                            NAME  \
# 0                                     NaN               GRI 305 Emissions
# 1    34cb5a35-0694-406d-990e-9eaa6b321880                Disclosure 305-1
# 2    8c040a69-2802-449e-b92c-8fcacb240517  Direct (Scope 1) GHG emissions
# ...

# %%
df.isnull().sum()
# Out:
# ID                      0
# TYPE                    0
# PARENT                  7
# NAME                    5
# SOURCE                 93
# TARGET                 92
# REFERENCE_MODEL_ID    102
# TERM_ID               102
# LABEL                 102
# Unnamed: 9            102
# PROPERTIES:           102
# Description            95
# Required?              23
# Quant_Qual             23
# dtype: int64
